# %% [markdown]
# ## PyPI - Python Package Index
# * https://pypi.org/
# * Repository for open-source third-party python packages
# * Similar to RubyGems in Ruby world
# * NPM in Node.js
# * Like third party libs in Java like commons, lombok etc
# * We can use `pip install`

# %%
pip install requests
pip install colorama

# %%
# start python session. From command prompt type - python

from colorama import init
init()
from colorama import Fore

print(Fore.RED + "some red color text")
# some red color text

print(Fore.GREEN + "some green color text")
# some green color text

quit()

# %%
# python with excel
# google - python package for excel
pip install openpyxl
